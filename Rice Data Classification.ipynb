# %% [markdown]
# # RICE DATA CLASSIFICATION
#                                  BY-SANCHI SINGHAL

# %% [markdown]
# LOADING THE RICE DATASET

# %%
import pandas as pd  #importing pandas to work on rice dataset
df=pd.read_csv("Rice_data.csv")       #reading the file in csv format
df
# Out:
#         AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  \
# 0       7805    437.915    209.8215     48.0221        0.9735   99.6877
# 1       7503    340.757    138.3361     69.8417        0.8632   97.7400
# 2       5124    314.617    141.9803     46.5784        0.9447   80.7718
# 3       7990    437.085    201.4386     51.2245        0.9671  100.8622
# 4       7433    342.893    140.3350     68.3927        0.8732   97.2830
# ...      ...        ...         ...         ...           ...       ...
# 74995   5551    285.911    114.1695     62.9079        0.8345   84.0699
# 74996   7696    322.703    121.3900     81.1375        0.7438   98.9892
# 74997   7579    339.295    136.3125     71.2866        0.8524   98.2338
# 74998  15174    489.502    200.9486     97.6282        0.8740  138.9969
# 74999  12931    452.635    185.5138     90.2651        0.8736  128.3131
#
#        SOLIDITY  CONVEX_AREA  EXTENT  ASPECT_RATIO  ...  ALLdaub4L  ALLdaub4a  \
# ...

# %% [markdown]
# SUMMARIZING THE DATASET

# %%
df.shape
# Out:
# (75000, 107)

# %%
df.describe()
# Out:
#                AREA     PERIMETER    MAJOR_AXIS    MINOR_AXIS  ECCENTRICITY  \
# count  75000.000000  75000.000000  75000.000000  75000.000000  75000.000000
# mean    8379.197507    378.169453    161.805540     66.829335      0.886077
# std     3119.209274     70.597008     36.461005     16.689269      0.071906
# min     3929.000000    261.040000     96.968300     34.673000      0.627700
# 25%     6259.000000    316.431500    132.623500     49.650200      0.846100
# 50%     7345.000000    351.261000    149.343950     69.183900      0.885600
# 75%     8901.000000    444.986000    197.462025     75.814125      0.950800
# max    21019.000000    593.698000    255.647200    113.441100      0.986800
#
#             EQDIASQ      SOLIDITY   CONVEX_AREA        EXTENT  ASPECT_RATIO  \
# count  75000.000000  75000.000000  75000.000000  75000.000000  75000.000000
# mean     101.731251      0.975896   8584.862320      0.633226      2.597063
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75000 entries, 0 to 74999
# Columns: 107 entries, AREA to CLASS
# dtypes: float64(95), int64(11), object(1)
# memory usage: 61.2+ MB

# %%
df.value_counts()
# Out:
# AREA   PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY  EQDIASQ   SOLIDITY  CONVEX_AREA  EXTENT  ASPECT_RATIO  ROUNDNESS  COMPACTNESS  SHAPEFACTOR_1  SHAPEFACTOR_2  SHAPEFACTOR_3  SHAPEFACTOR_4  meanRR    meanRG    meanRB    StdDevRR  StdDevRG  StdDevRB  skewRR   skewRG   skewRB   kurtosisRR  kurtosisRG  kurtosisRB  entropyRR     entropyRG     entropyRB     meanH   meanS   meanV   StdDevH  StdDevS  StdDevV  skewH     skewS    skewV    kurtosisH  kurtosisS  kurtosisV  entropyH   entropyS  entropyV   meanL     meanA     meanB     StdDevL  StdDevA  StdDevB  skewL    skewA    skewB    kurtosisL  kurtosisA  kurtosisB  entropyL      entropyA     entropyB     meanY     meanCb    meanCr    StdDevY  StdDevCb  StdDevCr  skewY    skewCb   skewCr   kurtosisY  kurtosisCb  kurtosisCr  entropyY      entropyCb    entropyCr    meanXX  meanYY  meanZZ  StdDevXX  StdDevYY  StdDevZZ  skewXX   skewYY   skewZZ   kurtosisXX  kurtosisYY  kurtosisZZ  entropyXX  entropyYY  entropyZZ  ALLdaub4RR  ALLdaub4RG  AL
# ...

# %%
print(df.isnull().sum())
# Out:
# AREA            0
# PERIMETER       0
# MAJOR_AXIS      0
# MINOR_AXIS      0
# ECCENTRICITY    0
#                ..
# ALLdaub4Cr      0
# ALLdaub4XX      0
# ALLdaub4YY      0
# ALLdaub4ZZ      0
# CLASS           0
# Length: 107, dtype: int64

# %%
df["CLASS"].value_counts()
# Out:
# Basmati      15000
# Ipsala       15000
# Karacadag    15000
# Arborio      15000
# Jasmine      15000
# Name: CLASS, dtype: int64

# %% [markdown]
# REMOVING NULL VALUES FROM THE DATASET

# %%
df1=df.dropna()
df1
# Out:
#         AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  \
# 0       7805    437.915    209.8215     48.0221        0.9735   99.6877
# 1       7503    340.757    138.3361     69.8417        0.8632   97.7400
# 2       5124    314.617    141.9803     46.5784        0.9447   80.7718
# 3       7990    437.085    201.4386     51.2245        0.9671  100.8622
# 4       7433    342.893    140.3350     68.3927        0.8732   97.2830
# ...      ...        ...         ...         ...           ...       ...
# 74995   5551    285.911    114.1695     62.9079        0.8345   84.0699
# 74996   7696    322.703    121.3900     81.1375        0.7438   98.9892
# 74997   7579    339.295    136.3125     71.2866        0.8524   98.2338
# 74998  15174    489.502    200.9486     97.6282        0.8740  138.9969
# 74999  12931    452.635    185.5138     90.2651        0.8736  128.3131
#
#        SOLIDITY  CONVEX_AREA  EXTENT  ASPECT_RATIO  ...  ALLdaub4L  ALLdaub4a  \
# ...

# %% [markdown]
# LABELLING THE TARGET VALUES

# %%
dict={"Basmati":0,"Arborio":1,"Jasmine":2,"Ipsala":3,"Karacadag":4}
df1["CLASS"]=df1["CLASS"].map(dict)
df1["CLASS"].value_counts()
# Out:
# <ipython-input-9-0b6dc676e308>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["CLASS"]=df1["CLASS"].map(dict)
# 0    15000
# 1    15000
# 4    15000
# 2    14998
# 3    14994
# Name: CLASS, dtype: int64

# %% [markdown]
# DIVIDING THE DATASET INTO INDEPENDENT VALUES AND TARGET VALUES

# %%
x=df1.iloc[0:,:-1] 
print(x)
y=df1["CLASS"]
print(x.shape)
print(y.shape)
print(y)
# Out:
#         AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  \
# 0       7805    437.915    209.8215     48.0221        0.9735   99.6877
# 1       7503    340.757    138.3361     69.8417        0.8632   97.7400
# 2       5124    314.617    141.9803     46.5784        0.9447   80.7718
# 3       7990    437.085    201.4386     51.2245        0.9671  100.8622
# 4       7433    342.893    140.3350     68.3927        0.8732   97.2830
# ...      ...        ...         ...         ...           ...       ...
# 74995   5551    285.911    114.1695     62.9079        0.8345   84.0699
# 74996   7696    322.703    121.3900     81.1375        0.7438   98.9892
# 74997   7579    339.295    136.3125     71.2866        0.8524   98.2338
# 74998  15174    489.502    200.9486     97.6282        0.8740  138.9969
# 74999  12931    452.635    185.5138     90.2651        0.8736  128.3131
#
#        SOLIDITY  CONVEX_AREA  EXTENT  ASPECT_RATIO  ...  ALLdaub4V  ALLdaub4L  \
# ...

# %% [markdown]
# DATA SPLITTING FOR TRAINING AND TESTING

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)
print(x.shape)
print(x_train.shape)
print(x_test.shape)
# Out:
# (74992, 106)
# (52494, 106)
# (22498, 106)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.model_selection import GridSearchCV
import numpy as np

# %% [markdown]
# IMPORTING MODELS

# %%
from sklearn.linear_model import Perceptron
clf1=Perceptron()
from sklearn.linear_model import LogisticRegression
clf2=LogisticRegression()
from sklearn.tree import DecisionTreeClassifier
clf3=DecisionTreeClassifier()

# %% [markdown]
# #### Without Standardizing

# %% [markdown]
# MODEL 1: Perceptron

# %%
clf1.fit(x_train,y_train)
y_test_pred1=clf1.predict(x_test)
y_train_pred1=clf1.predict(x_train)
train_acc1=accuracy_score(y_train,y_train_pred1)
test_acc1=accuracy_score(y_test,y_test_pred1)
print("Training Acc=",train_acc1)
print("Testing Acc=",test_acc1)
cr1=classification_report(y_test,y_test_pred1)
print(cr1)
cm1=confusion_matrix(y_test,y_test_pred1)
print(cm1)
sns.heatmap(cm1,annot=True,cbar=False)
# Out:
# Training Acc= 0.6011163180553968
# Testing Acc= 0.604587074406614
#               precision    recall  f1-score   support
#
#            0       0.93      0.24      0.38      4532
#            1       0.80      0.00      0.00      4436
#            2       0.37      0.98      0.54      4476
#            3       0.93      1.00      0.96      4484
#            4       0.76      0.80      0.78      4570
#
#     accuracy                           0.60     22498
#    macro avg       0.76      0.60      0.53     22498
# weighted avg       0.76      0.60      0.54     22498
#
# [[1089    0 2342   17 1084]
#  [   0    4 4136  285   11]
#  [  15    1 4395   18   47]
#  [   0    0    5 4479    0]
#  [  68    0  865    2 3635]]
# <AxesSubplot:>

# %% [markdown]
# MODEL 2: Logistic Regression

# %%
clf2.fit(x_train,y_train)
y_test_pred2=clf2.predict(x_test)
y_train_pred2=clf2.predict(x_train)
train_acc2=accuracy_score(y_train,y_train_pred2)
test_acc2=accuracy_score(y_test,y_test_pred2)
print("Training Acc=",train_acc2)
print("Testing Acc=",test_acc2)
cr2=classification_report(y_test,y_test_pred2)
print(cr2)
cm2=confusion_matrix(y_test,y_test_pred2)
print(cm2)
sns.heatmap(cm2,annot=True,cbar=False)
# Out:
# Training Acc= 0.7789652150721987
# Testing Acc= 0.7792248199839986
#               precision    recall  f1-score   support
#
#            0       0.73      0.78      0.76      4532
#            1       0.66      0.87      0.75      4436
#            2       0.67      0.45      0.54      4476
#            3       0.98      0.99      0.99      4484
#            4       0.85      0.81      0.83      4570
#
#     accuracy                           0.78     22498
#    macro avg       0.78      0.78      0.77     22498
# weighted avg       0.78      0.78      0.77     22498
#
# [[3529  168  438   11  386]
#  [  81 3839  413   72   31]
#  [ 568 1672 2022    4  210]
#  [   0   34    0 4450    0]
#  [ 634   99  145    1 3691]]
# C:\Users\sanch\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
# ...

# %% [markdown]
# MODEL 3: Decision Tree Classifier

# %%
clf3.fit(x_train,y_train)
y_test_pred3=clf3.predict(x_test)
y_train_pred3=clf3.predict(x_train)
train_acc3=accuracy_score(y_train,y_train_pred3)
test_acc3=accuracy_score(y_test,y_test_pred3)
print("Training Acc=",train_acc3)
print("Testing Acc=",test_acc3)
cr3=classification_report(y_test,y_test_pred3)
print(cr3)
cm3=confusion_matrix(y_test,y_test_pred3)
print(cm3)
sns.heatmap(cm3,annot=True,cbar=False)
# Out:
# Training Acc= 1.0
# Testing Acc= 0.9953773668770557
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4532
#            1       0.99      0.99      0.99      4436
#            2       0.99      0.99      0.99      4476
#            3       1.00      1.00      1.00      4484
#            4       1.00      0.99      1.00      4570
#
#     accuracy                           1.00     22498
#    macro avg       1.00      1.00      1.00     22498
# weighted avg       1.00      1.00      1.00     22498
#
# [[4510    0   22    0    0]
#  [   1 4410   14    0   11]
#  [   9   15 4447    2    3]
#  [   0    3    1 4480    0]
#  [   0   18    5    0 4547]]
# <AxesSubplot:>

# %% [markdown]
# #### Standardizing

# %%
sc.fit(x_train)
x_train_std=sc.transform(x_train)
x_test_std=sc.transform(x_test)

# %% [markdown]
# MODEL 1: Perceptron

# %%
clf1.fit(x_train_std,y_train)
y_test_pred1s=clf1.predict(x_test_std)
y_train_pred1s=clf1.predict(x_train_std)
train_acc1s=accuracy_score(y_train,y_train_pred1s)
test_acc1s=accuracy_score(y_test,y_test_pred1s)
print("Training Acc=",train_acc1s)
print("Testing Acc=",test_acc1s)
cr1s=classification_report(y_test,y_test_pred1s)
print(cr1s)
cm1s=confusion_matrix(y_test,y_test_pred1s)
print(cm1s)
sns.heatmap(cm1s,annot=True,cbar=False)
# Out:
# Training Acc= 0.9987236636567989
# Testing Acc= 0.9980442706018313
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4532
#            1       1.00      1.00      1.00      4436
#            2       1.00      1.00      1.00      4476
#            3       1.00      1.00      1.00      4484
#            4       1.00      1.00      1.00      4570
#
#     accuracy                           1.00     22498
#    macro avg       1.00      1.00      1.00     22498
# weighted avg       1.00      1.00      1.00     22498
#
# [[4526    0    6    0    0]
#  [   0 4423    9    1    3]
#  [  10    7 4459    0    0]
#  [   0    0    0 4484    0]
#  [   0    8    0    0 4562]]
# <AxesSubplot:>

# %% [markdown]
# MODEL 2: Logistic Regression

# %%
clf2.fit(x_train_std,y_train)
y_test_pred2s=clf2.predict(x_test_std)
y_train_pred2s=clf2.predict(x_train_std)
train_acc2s=accuracy_score(y_train,y_train_pred2s)
test_acc2s=accuracy_score(y_test,y_test_pred2s)
print("Training Acc=",train_acc2s)
print("Testing Acc=",test_acc2s)
cr2s=classification_report(y_test,y_test_pred2s)
print(cr2s)
cm2s=confusion_matrix(y_test,y_test_pred2s)
print(cm2s)
sns.heatmap(cm2s,annot=True,cbar=False)
# Out:
# C:\Users\sanch\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Training Acc= 0.9993142073379815
# Testing Acc= 0.9981776157880701
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4532
#            1       1.00      1.00      1.00      4436
#            2       1.00      1.00      1.00      4476
#            3       1.00      1.00      1.00      4484
#            4       1.00      1.00      1.00      4570
#
#     accuracy                           1.00     22498
# ...

# %% [markdown]
# MODEL 3: Decision Tree Classifier

# %%
clf3.fit(x_train_std,y_train)
y_test_pred3s=clf3.predict(x_test_std)
y_train_pred3s=clf3.predict(x_train_std)
train_acc3s=accuracy_score(y_train,y_train_pred3s)
test_acc3s=accuracy_score(y_test,y_test_pred3s)
print("Training Acc=",train_acc3s)
print("Testing Acc=",test_acc3s)
cr3s=classification_report(y_test,y_test_pred3s)
print(cr3s)
cm3s=confusion_matrix(y_test,y_test_pred3s)
print(cm3s)
sns.heatmap(cm3s,annot=True,cbar=False)
# Out:
# Training Acc= 1.0
# Testing Acc= 0.9952884700862299
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4532
#            1       0.99      0.99      0.99      4436
#            2       0.99      0.99      0.99      4476
#            3       1.00      1.00      1.00      4484
#            4       1.00      0.99      1.00      4570
#
#     accuracy                           1.00     22498
#    macro avg       1.00      1.00      1.00     22498
# weighted avg       1.00      1.00      1.00     22498
#
# [[4510    0   22    0    0]
#  [   1 4407   13    1   14]
#  [  10   15 4447    2    2]
#  [   0    3    0 4481    0]
#  [   0   19    4    0 4547]]
# <AxesSubplot:>

# %% [markdown]
# ### With Hyper Parameter tuning

# %% [markdown]
# MODEL 1:Perceptron

# %%
param_grid1 = {"tol":[1e-3],
               'max_iter':[100]
              } 
grid1 = GridSearchCV(clf1, param_grid1,cv=5)
grid1.fit(x_train, y_train)
y_test_pred1t=grid1.predict(x_test)
y_train_pred1t=grid1.predict(x_train)
train_acc1t=accuracy_score(y_train,y_train_pred1t)
test_acc1t=accuracy_score(y_test,y_test_pred1t)
print("Training Acc=",train_acc1t)
print("Testing Acc=",test_acc1t)
cr1t=classification_report(y_test,y_test_pred1t)
print(cr1t)
cm1t=confusion_matrix(y_test,y_test_pred1t)
print(cm1t)
sns.heatmap(cm1t,annot=True,cbar=False)
# Out:
# Training Acc= 0.6011163180553968
# Testing Acc= 0.604587074406614
#               precision    recall  f1-score   support
#
#            0       0.93      0.24      0.38      4532
#            1       0.80      0.00      0.00      4436
#            2       0.37      0.98      0.54      4476
#            3       0.93      1.00      0.96      4484
#            4       0.76      0.80      0.78      4570
#
#     accuracy                           0.60     22498
#    macro avg       0.76      0.60      0.53     22498
# weighted avg       0.76      0.60      0.54     22498
#
# [[1089    0 2342   17 1084]
#  [   0    4 4136  285   11]
#  [  15    1 4395   18   47]
#  [   0    0    5 4479    0]
#  [  68    0  865    2 3635]]
# <AxesSubplot:>

# %% [markdown]
# MODEL 2: Logistic Regression

# %%
c_space=np.logspace(-5,8,15)
param_grid2 = {'C': c_space,
              "multi_class":['auto', 'ovr', 'multinomial']}
grid2 = GridSearchCV(clf2, param_grid2, cv=5)
grid2.fit(x_train, y_train)
y_test_pred2t=grid2.predict(x_test)
y_train_pred2t=grid2.predict(x_train)
train_acc2t=accuracy_score(y_train,y_train_pred2t)
test_acc2t=accuracy_score(y_test,y_test_pred2t)
print("Training Acc=",train_acc2t)
print("Testing Acc=",test_acc2t)
cr2t=classification_report(y_test,y_test_pred2t)
print(cr2t)
cm2t=confusion_matrix(y_test,y_test_pred2t)
print(cm2t)
sns.heatmap(cm2t,annot=True,cbar=False)
# Out:
# C:\Users\sanch\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sanch\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# MODEL 3: Decision Tree Classifier

# %%
from scipy.stats import randint
c_space=np.logspace(-5,8,15)
param_grid3 = {"max_depth": [3, None],
              "criterion": ["gini", "entropy"]}
grid3 = GridSearchCV(clf3, param_grid3, cv=5)
grid3.fit(x_train, y_train)
y_test_pred3t=grid3.predict(x_test)
y_train_pred3t=grid3.predict(x_train)
train_acc3t=accuracy_score(y_train,y_train_pred3t)
test_acc3t=accuracy_score(y_test,y_test_pred3t)
print("Training Acc=",train_acc3t)
print("Testing Acc=",test_acc3t)
cr3t=classification_report(y_test,y_test_pred3t)
print(cr3t)
cm3t=confusion_matrix(y_test,y_test_pred3t)
print(cm3t)
sns.heatmap(cm3t,annot=True,cbar=False)
# Out:
# Training Acc= 1.0
# Testing Acc= 0.9962663347853142
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4532
#            1       0.99      1.00      1.00      4436
#            2       0.99      0.99      0.99      4476
#            3       1.00      1.00      1.00      4484
#            4       1.00      1.00      1.00      4570
#
#     accuracy                           1.00     22498
#    macro avg       1.00      1.00      1.00     22498
# weighted avg       1.00      1.00      1.00     22498
#
# [[4510    0   22    0    0]
#  [   0 4422    7    1    6]
#  [  14   13 4446    2    1]
#  [   1    2    3 4478    0]
#  [   0    8    3    1 4558]]
# <AxesSubplot:>

# %% [markdown]
# ### Model Comparison

# %% [markdown]
# #### Before Standardizing

# %%
acc={"Perceptron":test_acc1,"Logistic Regression":test_acc2,"Decision Tree Classifier":test_acc3}
cr={"Perceptron":cr1,"Logistic Regression":cr2,"Decision Tree Classifier":cr3}
print("\t\t\t\t\tBefore Standardizing")
print("\nTesting Accuracy: ")
print(acc)
print("\nConfusion Matrices: ")
for i, j in cr.items():
    print(i,":\n",j)
print("Heatmaps: ")
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.heatmap(cm1,annot=True,cbar=False)
plt.title("Perceptron")
plt.subplot(2,2,2)
sns.heatmap(cm2,annot=True,cbar=False)
plt.title("Logistic Regression")
plt.subplot(2,2,3)
sns.heatmap(cm3,annot=True,cbar=False)
plt.title("Decision Tree Classifier")
# Out:
# 					Before Standardizing
#
# Testing Accuracy:
# {'Perceptron': 0.604587074406614, 'Logistic Regression': 0.7792248199839986, 'Decision Tree Classifier': 0.9953773668770557}
#
# Confusion Matrices:
# Perceptron :
#                precision    recall  f1-score   support
#
#            0       0.93      0.24      0.38      4532
#            1       0.80      0.00      0.00      4436
#            2       0.37      0.98      0.54      4476
#            3       0.93      1.00      0.96      4484
#            4       0.76      0.80      0.78      4570
#
#     accuracy                           0.60     22498
#    macro avg       0.76      0.60      0.53     22498
# weighted avg       0.76      0.60      0.54     22498
#
# Logistic Regression :
#                precision    recall  f1-score   support
#
#            0       0.73      0.78      0.76      4532
#            1       0.66      0.87      0.75      4436
#            2       0.67      0.45      0.54      4476
# ...

# %% [markdown]
# #### After Standardizing

# %%
accs={"Perceptron":test_acc1s,"Logistic Regression":test_acc2s,"Decision Tree Classifier":test_acc3s}
crs={"Perceptron":cr1s,"Logistic Regression":cr2s,"Decision Tree Classifier":cr3s}
print("\t\t\t\t\tAfter Standardizing")
print("\nTesting Accuracy: ")
print(accs)
print("\nConfusion Matrices: ")
for i, j in crs.items():
    print(i,":\n",j)
print("Heatmaps: ")
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.heatmap(cm1s,annot=True,cbar=False)
plt.title("Perceptron")
plt.subplot(2,2,2)
sns.heatmap(cm2s,annot=True,cbar=False)
plt.title("Logistic Regression")
plt.subplot(2,2,3)
sns.heatmap(cm3s,annot=True,cbar=False)
plt.title("Decision Tree Classifierr")
# Out:
# 					After Standardizing
#
# Testing Accuracy:
# {'Perceptron': 0.9980442706018313, 'Logistic Regression': 0.9981776157880701, 'Decision Tree Classifier': 0.9952884700862299}
#
# Confusion Matrices:
# Perceptron :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4532
#            1       1.00      1.00      1.00      4436
#            2       1.00      1.00      1.00      4476
#            3       1.00      1.00      1.00      4484
#            4       1.00      1.00      1.00      4570
#
#     accuracy                           1.00     22498
#    macro avg       1.00      1.00      1.00     22498
# weighted avg       1.00      1.00      1.00     22498
#
# Logistic Regression :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4532
#            1       1.00      1.00      1.00      4436
#            2       1.00      1.00      1.00      4476
# ...

# %% [markdown]
# #### With Hyper Parameter Tuning

# %%
acct={"Perceptron":test_acc1t,"Logistic Regression":test_acc2t,"Decision Tree Classifier":test_acc3t}
crt={"Perceptron":cr1t,"Logistic Regression":cr2t,"Decision Tree Classifier":cr3t}
print("\t\t\t\t\tAfter Hyper Parameter Tuning")
print("\nTesting Accuracy: ")
print(acct)
print("\nConfusion Matrices: ")
for i, j in crt.items():
    print(i,":\n",j)
print("Heatmaps: ")
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.heatmap(cm1t,annot=True,cbar=False)
plt.title("Perceptron")
plt.subplot(2,2,2)
sns.heatmap(cm2t,annot=True,cbar=False)
plt.title("Logistic Regression")
plt.subplot(2,2,3)
sns.heatmap(cm3t,annot=True,cbar=False)
plt.title("Decision Tree Classifierr")
# Out:
# 					After Hyper Parameter Tuning
#
# Testing Accuracy:
# {'Perceptron': 0.604587074406614, 'Logistic Regression': 0.810072006400569, 'Decision Tree Classifier': 0.9962663347853142}
#
# Confusion Matrices:
# Perceptron :
#                precision    recall  f1-score   support
#
#            0       0.93      0.24      0.38      4532
#            1       0.80      0.00      0.00      4436
#            2       0.37      0.98      0.54      4476
#            3       0.93      1.00      0.96      4484
#            4       0.76      0.80      0.78      4570
#
#     accuracy                           0.60     22498
#    macro avg       0.76      0.60      0.53     22498
# weighted avg       0.76      0.60      0.54     22498
#
# Logistic Regression :
#                precision    recall  f1-score   support
#
#            0       0.72      0.80      0.75      4532
#            1       0.75      0.86      0.80      4436
#            2       0.73      0.61      0.66      4476
# ...

# %% [markdown]
# OUTCOMES

# %%
print("The best model out of Perceptron,Logistic Regression and Decision Tree Classifier is:")
Key1 = max(acc, key= lambda x: acc[x])
Key2 = max(accs, key= lambda x: accs[x])
Key3 = max(acct, key= lambda x: acct[x])
print("Before Standardizing: ",Key1)
print("After Standardizing: ",Key2)
print("With Hyper Parameter Tuning: ",Key3)
# Out:
# The best model out of Perceptron,Logistic Regression and Decision Tree Classifier is:
# Before Standardizing:  Decision Tree Classifier
# After Standardizing:  Logistic Regression
# With Hyper Parameter Tuning:  Decision Tree Classifier
